# %% [markdown]
# # Prediction Analysis

# %%
import WebScraper
import pandas as pd
import fbprophet
import matplotlib.pyplot as plt

# %%
test_data = []

for i in range(0, 100):
    scraper = WebScraper.Ticker("AAPL")
    test_data.append(scraper.scrape())

# %%
plt.plot(test_data)
plt.grid()
plt.show()
